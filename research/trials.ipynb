# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1z0mreUtRmR-P-magILsDR3T7M6IkGXtY/view?usp=sharing"
file_id = url.split("/")[-2]
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY
# From (redirected): https://drive.google.com/uc?id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY&confirm=t&uuid=73499785-477e-42e9-839c-128b1ce81127
# To: c:\Users\ujjwa\Documents\mlops_project_github\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:14<00:00, 3.35MB/s]
# 'Chest-CT-Scan-data.zip'
